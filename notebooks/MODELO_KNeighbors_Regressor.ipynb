# %% [markdown]
# # Modelo KNeighbors para predecir la presión

# %%
from pathlib import Path
from pprint import pprint

import numpy as np
import pandas as pd

# Importar los estimadores y escaladores necesarios
from sklearn.preprocessing import RobustScaler, StandardScaler, MinMaxScaler
from scipy.stats import randint, uniform

# Importar GridSearchCV para realizar la búsqueda de hiperparámetros
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

# Importar el KNeighborsRegressor...
from sklearn.neighbors import KNeighborsRegressor

# Selección del Modelo y las métricas...
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

from sklearn.pipeline import Pipeline

# Trackeo de experimentos
import mlflow
from mlflow.models import infer_signature
import mlflow.sklearn
import dagshub

import matplotlib.pyplot as plt
import seaborn as sns

import joblib

# %%
mlflow.sklearn.autolog()

# %%
# Te dará un link para que te logees en dagshub
dagshub.init(repo_owner='guillermovc', repo_name='MLOps-grinding', mlflow=True)
# Out:
# Initialized MLflow to track repo "guillermovc/MLOps-grinding"
# Repository guillermovc/MLOps-grinding initialized!

# %% [markdown]
# ## Cargar el DataFrame

# %%
# Definir la ruta de los datos
data_path: Path = Path(r"../data/processed")
if not data_path.exists():
    print(f"El path {data_path} no existe, favor de revisar.")

# Imprimir archivos en la carpeta de datos
pprint(list(data_path.glob("*")))
# Out:
# [WindowsPath('../data/processed/df_model_no_outliers.parquet'),
#  WindowsPath('../data/processed/df_model_tidy.parquet'),
#  WindowsPath('../data/processed/df_model_tidy_lasso.parquet'),
#  WindowsPath('../data/processed/df_model_tidy_lasso_test.parquet'),
#  WindowsPath('../data/processed/df_model_tidy_lasso_train.parquet'),
#  WindowsPath('../data/processed/df_model_tidy_lasso_val.parquet')]

# %%
parquet_path = data_path / "df_model_tidy.parquet"

df = pd.read_parquet(parquet_path)
df
# Out:
#                       date  velocidad      potencia  rendimiento      ruido  \
# 0      2022-11-15 00:07:50  75.761029  39281.348296    65.653747  22.932414
# 1      2022-11-15 00:08:00  75.761029  39850.320731    65.691489  22.932414
# 2      2022-11-15 00:08:10  75.761029  39761.319456    65.783858  21.329909
# 3      2022-11-15 00:08:20  75.761029  39761.319456    65.906084  21.329909
# 4      2022-11-15 00:08:30  75.761029  39665.960948    65.986245  22.538648
# ...                    ...        ...           ...          ...        ...
# 248668 2022-12-14 23:59:20  75.494482  41194.875702    71.307249   8.845677
# 248669 2022-12-14 23:59:30  75.496079  41194.875702    71.403265   8.845677
# 248670 2022-12-14 23:59:40  75.497677  40686.296989    71.458539   8.845677
# 248671 2022-12-14 23:59:50  75.499274  40686.296989    71.513813   8.845677
# 248672 2022-12-15 00:00:00  75.499274  40594.117098    71.512283   9.922163
#
#               p80        f80  per_solidos         wi       spi  imp_criticos  \
# 0       64.260113  36.574719    71.583049  94.815049  54.50695      7.101110
# 1       64.260113  36.555098    71.579590  94.815049  54.50695      7.191338
# 2       64.260113  36.535478    71.585002  94.815049  54.50695      7.281566
# 3       64.260113  36.515857    71.598714  94.815049  54.50695      7.371795
# 4       64.260113  36.583533    71.615886  94.815049  54.50695      7.462023
# ...           ...        ...          ...        ...       ...           ...
# 248668  26.446656  45.849870    77.265464  92.573475  38.54322      0.900937
# 248669  26.446656  45.931528    77.298097  92.573475  38.54322      0.899591
# 248670  26.446656  46.134072    77.327109  92.573475  38.54322      0.898244
# 248671  26.446656  46.336617    77.356121  92.573475  38.54322      0.896897
# 248672  26.446656  46.590890    77.381390  92.573475  38.54322      0.904977
#
#         imp_estandares         jb    presion
# 0            65.598165   9.183127  87.199926
# 1            65.798205   9.180693  87.402467
# 2            65.998244   9.178803  87.492231
# 3            66.198283   9.178803  87.492231
# 4            66.398322   9.174560  87.564041
# ...                ...        ...        ...
# 248668       32.153835  89.318678  89.175128
# 248669       32.294106  89.318678  89.175128
# 248670       32.434377  89.314536  89.181349
# 248671       32.574649  89.314536  89.181349
# 248672       32.674668  89.310092  89.311585
#
# [248673 rows x 14 columns]

# %% [markdown]
# ## Definir `X` y `y`

# %%
X: np.ndarray = df.drop(columns=["presion", "date"]).to_numpy()
y: np.ndarray = df["presion"].to_numpy()

# Verificar tipos
print(f"{type(X) = }")
print(f"{type(y) = }")

# Verificar formas
print(f"{X.shape = }")
print(f"{y.shape = }")
# Out:
# type(X) = <class 'numpy.ndarray'>
# type(y) = <class 'numpy.ndarray'>
# X.shape = (248673, 12)
# y.shape = (248673,)

# %% [markdown]
# # Separar en entrenamiento y prueba
#
# Debido a que nuestro approach fue convertir de una serie de tiempo a un intervalo de 8 minutos, reservaremos primero los últimos días para probar el modelo.

# %%
# Tomar como prueba los datos desde el 12 de diciembre
date = "2022-12-12"

# Trackear desde que fecha tomaremos para testear
mlflow.log_param("test_start", date)

df[df["date"] > date]
# Out:
#                       date  velocidad      potencia  rendimiento     ruido  \
# 223274 2022-12-12 00:00:10  61.231838  32730.218758    45.510341  3.604423
# 223275 2022-12-12 00:00:20  61.164822  31598.631123    45.475115  3.791207
# 223276 2022-12-12 00:00:30  61.097805  31541.416018    45.407662  3.791207
# 223277 2022-12-12 00:00:40  61.030789  32142.174622    45.358609  3.791207
# 223278 2022-12-12 00:00:50  60.963772  32142.174622    45.345342  3.791207
# ...                    ...        ...           ...          ...       ...
# 248668 2022-12-14 23:59:20  75.494482  41194.875702    71.307249  8.845677
# 248669 2022-12-14 23:59:30  75.496079  41194.875702    71.403265  8.845677
# 248670 2022-12-14 23:59:40  75.497677  40686.296989    71.458539  8.845677
# 248671 2022-12-14 23:59:50  75.499274  40686.296989    71.513813  8.845677
# 248672 2022-12-15 00:00:00  75.499274  40594.117098    71.512283  9.922163
#
#               p80        f80  per_solidos         wi        spi  imp_criticos  \
# 223274  30.482594  29.060758    74.104980  96.306752  40.677938      0.000000
# 223275  30.482594  29.061834    74.140991  96.306752  40.677938      0.000000
# 223276  30.482594  29.062910    74.177002  96.306752  40.677938      0.000000
# 223277  30.482594  29.074935    74.213013  96.306752  40.677938      0.000000
# 223278  30.482594  29.040282    74.246053  96.306752  40.677938      0.000000
# ...           ...        ...          ...        ...        ...           ...
# 248668  26.446656  45.849870    77.265464  92.573475  38.543220      0.900937
# 248669  26.446656  45.931528    77.298097  92.573475  38.543220      0.899591
# 248670  26.446656  46.134072    77.327109  92.573475  38.543220      0.898244
# 248671  26.446656  46.336617    77.356121  92.573475  38.543220      0.896897
# 248672  26.446656  46.590890    77.381390  92.573475  38.543220      0.904977
#
#         imp_estandares         jb    presion
# 223274        8.332114  86.330692  87.412911
# 223275        8.282104  86.327785  87.228387
# 223276        8.232094  86.326418  86.801345
# 223277        8.182084  86.325211  86.303138
# 223278        8.132075  86.323845  86.186404
# ...                ...        ...        ...
# 248668       32.153835  89.318678  89.175128
# 248669       32.294106  89.318678  89.175128
# 248670       32.434377  89.314536  89.181349
# 248671       32.574649  89.314536  89.181349
# 248672       32.674668  89.310092  89.311585
#
# [25399 rows x 14 columns]

# %%
df[df["date"] > date].shape[0]*100/df.shape[0]
# Out:
# 10.213814929646563

# %% [markdown]
# Tomar los datos desde el 12 de diciembre representa un 10%

# %%
indice_sep = df[df["date"] > date].index[0]
print(f"{indice_sep = }")
# Out:
# indice_sep = 223274

# %%
X_train = X[:indice_sep]
y_train = y[:indice_sep]

X_test = X[indice_sep:]
y_test = y[indice_sep:]

print(f"{X_train.shape = }")
print(f"{X_test.shape = }")
print(f"{y_train.shape = }")
print(f"{y_test.shape = }")
# Out:
# X_train.shape = (223274, 12)
# X_test.shape = (25399, 12)
# y_train.shape = (223274,)
# y_test.shape = (25399,)

# %% [markdown]
# ## Tomar una pequeña muestra para búsqueda de hiperparámetros

# %%
# Ya que el entrenamiento es muy tardado, tomemos solo una parte de los datos
train_tune_size = 0.05
random_state = 42

# Trackear parámetro con mlflow
mlflow.log_param("train_tune_size", train_tune_size)
mlflow.log_param("random_state", random_state)

X_train_tune, _, y_train_tune, _ = train_test_split(X, y, train_size=train_tune_size, random_state=random_state)
print(f"Se usarán {X_train_tune.shape[0]:,} entradas para la búsqueda de hiperparámetros del modelo usando 5 folds)")
# Out:
# Se usarán 12,433 entradas para la búsqueda de hiperparámetros del modelo usando 5 folds)

# %%
X_train[0], y_train[0]
# Out:
# (array([7.57610289e+01, 3.92813483e+04, 6.56537472e+01, 2.29324136e+01,
#         6.42601135e+01, 3.65747190e+01, 7.15830485e+01, 9.48150489e+01,
#         5.45069496e+01, 7.10110967e+00, 6.55981655e+01, 9.18312691e+00]),
#  87.19992569135509)

# %%
X_train_tune[0], y_train_tune
# Out:
# (array([7.37423897e+01, 3.86456249e+04, 6.58788739e+01, 1.19071180e+01,
#         6.07410138e+01, 3.82929894e+01, 7.69291173e+01, 9.56950882e+01,
#         4.99704934e+01, 2.79842706e+00, 4.90046838e+01, 2.74756632e+01]),
#  array([86.41967241, 89.63006486, 83.89753244, ..., 87.70621262,
#         91.23965019, 88.10806561]))

# %% [markdown]
# ## Buscar hiperparámetros & Realizar el Experimento...

# %%
# Definimos la función que toma datos y devuelve los mejores parámetros

def buscar_mejores_hiperparametros(X, y, n_iters = 10, tipo_busqueda='random'):
    # Definir el modelo
    modelo = KNeighborsRegressor()

    # Crear un pipeline con parámetros por defecto (serán sustituidos)
    pipeline = Pipeline([
        ('scaler', None),
        ('regressor', modelo)
    ])

    # Definir la rejilla de hiperparámetros para GridSearch
    parametros_grid = {
        'scaler': [RobustScaler(), StandardScaler(), MinMaxScaler()],
        'regressor__n_neighbors': [3, 5, 7, 9],
        'regressor__weights': ['uniform', 'distance'],
        'regressor__algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
        'regressor__leaf_size': [10, 30, 50],
        'regressor__p': [1, 2]  # 1: Manhattan distance, 2: Euclidean distance
    }

    # Configurar la búsqueda de hiperparámetros
    if tipo_busqueda == 'grid':
        grid_search = GridSearchCV(estimator=pipeline, param_grid=parametros_grid,
                                   cv=5, n_jobs=-1, verbose=2, scoring='neg_mean_squared_error')
        
        # Realizar la búsqueda en cuadrícula
        grid_search.fit(X, y)
        
        # Obtener el mejor modelo y los mejores parámetros
        mejor_modelo = grid_search.best_estimator_
        mejores_parametros = grid_search.best_params_
        
        return mejor_modelo, mejores_parametros

    elif tipo_busqueda == 'random':
        # Definir la distribución de los hiperparámetros para RandomSearch
        parametros_distribucion = {
            'scaler': [RobustScaler(), StandardScaler(), MinMaxScaler()],
            'regressor__n_neighbors': randint(3, 10),
            'regressor__weights': ['uniform', 'distance'],
            'regressor__algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
            'regressor__leaf_size': randint(10, 50),
            'regressor__p': [1, 2]
        }
        
        # Configurar la búsqueda aleatoria
        random_search = RandomizedSearchCV(estimator=pipeline, param_distributions=parametros_distribucion,
                                           n_iter=n_iters, cv=5, n_jobs=-1, verbose=2, scoring='neg_mean_squared_error', random_state=42)
        
        # Realizar la búsqueda aleatoria
        random_search.fit(X, y)
        
        # Obtener el mejor modelo y los mejores parámetros
        mejor_modelo = random_search.best_estimator_
        mejores_parametros = random_search.best_params_
        
        return mejor_modelo, mejores_parametros

    else:
        raise ValueError("El parámetro 'tipo_busqueda' debe ser 'grid' o 'random'.")


# Definir el Experimento...

# Finalizar la ejecución actual de MLflow si está activa
if mlflow.active_run():
    mlflow.end_run()

# Establecer el nombre del experimento
nombre_experimento = "KNeighborsRegressor Experiment"
mlflow.set_experiment(nombre_experimento)

tune_n_iters = 20
tune_random = True

with mlflow.start_run():
    mlflow.log_param("tune_n_iters", tune_n_iters)
    mlflow.log_param("tune_random", tune_random)

    best_model, best_params = buscar_mejores_hiperparametros(X_train_tune, y_train_tune, n_iters = tune_n_iters)

    # Loguear los mejores parámetros en MLflow
    mlflow.log_params(best_params)

    # Registrar el modelo en MLflow
    mlflow.sklearn.log_model(best_model, "mejor_modelo")

    print(f"Mejor modelo: {best_model}")
    print(f"Mejores parámetros: {best_params}")
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# 2024/05/30 15:59:21 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "c:\ProgramData\anaconda3\Lib\site-packages\_distutils_hack\__init__.py:33: UserWarning: Setuptools is replacing distutils."
# 2024/05/30 15:59:37 INFO mlflow.sklearn.utils: Logging the 5 best runs, 15 runs will be omitted.
# Mejor modelo: Pipeline(steps=[('scaler', MinMaxScaler()),
#                 ('regressor',
#                  KNeighborsRegressor(algorithm='ball_tree', leaf_size=18,
#                                      n_neighbors=4, p=1, weights='distance'))])
# Mejores parámetros: {'regressor__algorithm': 'ball_tree', 'regressor__leaf_size': 18, 'regressor__n_neighbors': 4, 'regressor__p': 1, 'regressor__weights': 'distance', 'scaler': MinMaxScaler()}

# %% [markdown]
# # Entrenar el modelo con todos los datos

# %%
best_model.fit(X_train, y_train)
# Out:
# 2024/05/30 15:59:50 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '8725b8c896cf4c8d8aafefb02a279557', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow
# Pipeline(steps=[('scaler', MinMaxScaler()),
#                 ('regressor',
#                  KNeighborsRegressor(algorithm='ball_tree', leaf_size=18,
#                                      n_neighbors=4, p=1, weights='distance'))])

# %% [markdown]
# # Guardar el modelo

# %%
model_filename = '../models/best_kneighbors_regressor.pkl'

# %%
joblib.dump(best_model, model_filename)
print(f"Modelo guardado en {model_filename}")
# Out:
# Modelo guardado en ../models/best_kneighbors_regressor.pkl

# %%
# Cargar el modelo desde el archivo
loaded_model = joblib.load(model_filename)
print(f"Modelo cargado: {loaded_model}")
# Out:
# Modelo cargado: Pipeline(steps=[('scaler', MinMaxScaler()),
#                 ('regressor',
#                  KNeighborsRegressor(algorithm='ball_tree', leaf_size=18,
#                                      n_neighbors=4, p=1, weights='distance'))])

# %%
y_pred = loaded_model.predict(X_test)

# Calcular las métricas
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

# %%
print(f"MAE: {mae:,.4f}")
print(f"MSE: {mse:,.4f}")
print(f"RMSE: {rmse:,.4f}")
print(f"R^2: {r2:,.4f}")
# Out:
# MAE: 3.8121
# MSE: 29.3150
# RMSE: 5.4143
# R^2: -1.2468

# %%
# Loguear métricas en MLflow
mlflow.log_metric("MAE", mae)
mlflow.log_metric("MSE", mse)
mlflow.log_metric("RMSE", rmse)
mlflow.log_metric("R2", r2)

# %% [markdown]
# # Graficar `y_true` vs `y_pred`

# %%
# Crear la figura y los ejes
plt.figure(figsize=(12, 8))

# Ploteo de valores reales vs predichos con seaborn
sns.scatterplot(x=y_test, y=y_pred, color='salmon', s=50, label='Predicted Values')

# Ploteo de la línea de identidad (y = x)
max_val = max(max(y_test), max(y_pred))
min_val = min(min(y_test), min(y_pred))
plt.plot([min_val, max_val], [min_val, max_val], '--', color='black', label='Identity Line (y=x)')

# Añadir recuadro con MAE y MSE
textstr = f'MAE: {mae:.2f}\nMSE: {mse:.2f}'
# Propiedades del recuadro
props = dict(boxstyle='round,pad=0.5', facecolor='white', edgecolor='black', alpha=0.5)
# Ubicación del recuadro
plt.text(0.02, 0.8, textstr, transform=plt.gca().transAxes, fontsize=12,
         verticalalignment='top', bbox=props)

# Añadir títulos y etiquetas
plt.title('Actual vs Predicted Values', fontsize=14)
plt.xlabel('Actual Values', fontsize=12)
plt.ylabel('Predicted Values', fontsize=12)
plt.legend()
plt.grid(True)

# Mostrar el gráfico
plt.show()

# %%
# Inferir la firma del modelo
signature = infer_signature(X_test, y_pred)

# Loguear el modelo en MLflow
mlflow.sklearn.log_model(
    sk_model=best_model,
    artifact_path="best_kneighbors_regressor",
    signature=signature,
    registered_model_name="kneighbors-regressor-model",
)
# Out:
# Successfully registered model 'kneighbors-regressor-model'.
# 2024/05/30 16:02:33 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: kneighbors-regressor-model, version 1
# Created version '1' of model 'kneighbors-regressor-model'.

# %%
mlflow.end_run()
